# %%
import pandas as pd

# %%
dados = pd.read_pickle("../parsed-data/dados.pd.pkl")

# %%
metadados = pd.read_pickle("../parsed-data/metadados.pd.pkl")

# %%
estabelecimentos = pd.read_pickle("../parsed-data/estabelecimentos.pd.pkl")

# %%
estabelecimentos
# Out:
#        COMPETENCIA    IBGE  UF              MUNICIPIO     CNES  \
# 0           202202  420460  SC               CRICIUMA   488593
# 1           202202  420340  SC      CAMPO BELO DO SUL   552828
# 2           202202  420430  SC              CONCORDIA   613207
# 3           202202  420480  SC            CURITIBANOS   604801
# 4           202202  420900  SC                JOACABA   614122
# ...            ...     ...  ..                    ...      ...
# 21445       202202  420900  SC                JOACABA  6792774
# 21446       202202  420910  SC              JOINVILLE  6802540
# 21447       202202  421690  SC  SAO LOURENCO DO OESTE  6804721
# 21448       202202  420300  SC                CACADOR  6781934
# 21449       202202  420380  SC              CANOINHAS  6806171
#
#                                            NOME FANTASIA  \
# 0                                    LABORATORIO DO POVO
# 1               EMANUELLY BORGES FISIOTERAPIA E ESTETICA
# ...
